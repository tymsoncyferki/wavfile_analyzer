# %%
from analysis import FileAnalyzer

# %%
analyzer = FileAnalyzer("example.wav")
# Out:
# /home/tymek/private/wavfile_analyzer/analysis.py:17: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   self.sample_rate, self.data_raw = wavfile.read(filepath)

# %%
y, x = analyzer.waveform_freq()

# %%
y.shape
# Out:
# (661126,)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y)
plt.xscale('log')
plt.show()
